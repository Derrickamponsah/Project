# %% [markdown]
# ### NAME: DERRICK AMPOMAH AMPONSAH
#
# ### INDEX NUMBER: 11347946
#
# ### CLASS: COMPUTER ENGINEERING

# %%
#IMPORTING LIBARIES
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#IMPORT csv file
dataset = pd.read_csv('red_wine.csv')

# %%
#VIEW DATASET
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#PREVIEW THE FIRST 10 ROWS
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#PREVIEW THE LAST 20 ROWS
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
#CHECKING BASIC INFORMATION
dataset.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#DESCRIBING DATA INFO
dataset.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#DROPPING ANY NULL VALUES
dataset.dropna
# Out:
# <bound method DataFrame.dropna of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#FINDING THE AVERAGE OF THE pH, SULPHATES AND ALCOHOL
print(f'The mean of the density is  {dataset.density.mean()}')

print(f'The mean of the pH content is  {dataset.pH.mean()}')

print(f'The mean of the sulphate content is {dataset.sulphates.mean()}')

print(f'The mean of the alcohol contentis  {dataset.alcohol.mean()}')
# Out:
# The mean of the density is  0.996745519399249
# The mean of the pH content is  3.3111131957473416
# The mean of the sulphate content is 0.6581488430268917
# The mean of the alcohol contentis  10.422983114446529

# %%
#FINDING THE MODE OF THE pH, SULPHATES AND ALCOHOL
print(f'The mode of the density is  {dataset.density.mode()}')

print(f'The mode of the pH content is  {dataset.pH.mode()}')

print(f'The mode of the sulphate content is {dataset.sulphates.mode()}')

print(f'The mode of the alcohol contentis  {dataset.alcohol.mode()}')
# Out:
# The mode of the density is  0    0.9972
# Name: density, dtype: float64
# The mode of the pH content is  0    3.3
# Name: pH, dtype: float64
# The mode of the sulphate content is 0    0.6
# Name: sulphates, dtype: float64
# The mode of the alcohol contentis  0    9.5
# Name: alcohol, dtype: float64

# %%
#FINDING THE MEDIAN OF THE pH, SULPHATES AND ALCOHOL
print(f'The median of the density is  {dataset.density.median()}')

print(f'The median of the pH content is  {dataset.pH.median()}')

print(f'The median of the sulphate content is {dataset.sulphates.median()}')

print(f'The median of the alcohol contentis  {dataset.alcohol.median()}')
# Out:
# The median of the density is  0.99675
# The median of the pH content is  3.31
# The median of the sulphate content is 0.62
# The median of the alcohol contentis  10.2

# %%
#FILTERING ITEMS IN THE DATASET
dataset.filter(items=['pH', 'alcohol'])
# Out:
#         pH  alcohol
# 0     3.51      9.4
# 1     3.20      9.8
# 2     3.26      9.8
# 3     3.16      9.8
# 4     3.51      9.4
# ...    ...      ...
# 1594  3.45     10.5
# 1595  3.52     11.2
# 1596  3.42     11.0
# 1597  3.57     10.2
# 1598  3.39     11.0
#
# [1599 rows x 2 columns]

# %%
dataset.filter(like = 'acid')
# Out:
#       fixed acidity  volatile acidity  citric acid
# 0               7.4             0.700         0.00
# 1               7.8             0.880         0.00
# 2               7.8             0.760         0.04
# 3              11.2             0.280         0.56
# 4               7.4             0.700         0.00
# ...             ...               ...          ...
# 1594            6.2             0.600         0.08
# 1595            5.9             0.550         0.10
# 1596            6.3             0.510         0.13
# 1597            5.9             0.645         0.12
# 1598            6.0             0.310         0.47
#
# [1599 rows x 3 columns]

# %%
dataset.filter(like = 'sul')
# Out:
#       free sulfur dioxide  total sulfur dioxide  sulphates
# 0                    11.0                  34.0       0.56
# 1                    25.0                  67.0       0.68
# 2                    15.0                  54.0       0.65
# 3                    17.0                  60.0       0.58
# 4                    11.0                  34.0       0.56
# ...                   ...                   ...        ...
# 1594                 32.0                  44.0       0.58
# 1595                 39.0                  51.0       0.76
# 1596                 29.0                  40.0       0.75
# 1597                 32.0                  44.0       0.71
# 1598                 18.0                  42.0       0.66
#
# [1599 rows x 3 columns]

# %%
#SORTING OF DATASET
dataset.sort_values('density')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1018            8.0             0.180         0.37             0.9      0.049
# 1017            8.0             0.180         0.37             0.9      0.049
# 1114            5.0             0.400         0.50             4.3      0.046
# 837             6.7             0.280         0.28             2.4      0.012
# 836             6.7             0.280         0.28             2.4      0.012
# ...             ...               ...          ...             ...        ...
# 555            15.5             0.645         0.49             4.2      0.095
# 442            15.6             0.685         0.76             3.7      0.100
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 14              8.9             0.620         0.18             3.8      0.176
#
# ...

# %%
#FINDING CORRELATION IN THE DATASET
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255282     0.671371
# volatile acidity          -0.255282          1.000000    -0.552334
# citric acid                0.671371         -0.552334     1.000000
# residual sugar             0.114743          0.002075     0.143577
# chlorides                  0.093866          0.061107     0.203944
# free sulfur dioxide       -0.153762         -0.010496    -0.061884
# total sulfur dioxide      -0.112632          0.076881     0.035533
# density                    0.667799          0.021796     0.365370
# pH                        -0.683021          0.234801    -0.541904
# sulphates                  0.183213         -0.260870     0.312770
# alcohol                   -0.061062         -0.202097     0.109903
# quality                    0.124639         -0.390721     0.226166
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# DATASET VISUALIZATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
dataset = pd.read_csv('red_wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x = dataset.alcohol
y = dataset.pH
plt.figure(figsize = (7,3))
plt.xlabel('alcohol')
plt.ylabel('pH')
plt.title('A Plot of Alcohol vrs pH')
plt.plot(x,y, marker = 'x')
plt.show()

# %%
x = dataset.alcohol
y = dataset.pH
plt.figure(figsize = (7,3))
plt.xlabel('alcohol')
plt.ylabel('pH')
plt.title('A Plot of Alcohol vrs pH')
plt.bar(x,y)
plt.show()

# %%
y1 = dataset.sulphates
x1= dataset.alcohol
plt.ylabel('Sulphate content')
plt.xlabel('Alcohol')
plt.title('A Graph of Sulphate content vrs Alcohol')
plt.bar(x1,y1)
# Out:
# <BarContainer object of 1599 artists>

# %%
plt.scatter(x1,y1, marker = '*')
plt.title('A Scatter diagram of Sulphate content VRS Alcohol')
plt.xlabel('Alcohol')
plt.ylabel('Sulphate content')
# Out:
# Text(0, 0.5, 'Sulphate content')

# %%
y2 = dataset.sulphates
x2= dataset.pH
plt.ylabel('Sulphate content')
plt.xlabel('pH')
plt.title('A Graph of Sulphate content vrs pH')
plt.bar(x2,y2)
# Out:
# <BarContainer object of 1599 artists>

# %%
y2 = dataset.sulphates
x2= dataset.pH
plt.ylabel('Sulphate content')
plt.xlabel('pH')
plt.title('A Graph of Sulphate content vrs pH')
plt.plot(x2,y2, marker = 'o')

# %% [markdown]
# ## REPORT ON THE GRAPHS OBTAINED ABOVE

# %% [markdown]
#  The first graph represent the plot of alcohol against pH where the x-axis represent the pH and y-axis represents the alcohol. After the plot, the points was centralised which indicates less relationship between the values of the alcohol and it pH.
#
#    The second graph is a bar graph of the first graph. From the bar graph, it can be deduced that, the relationship between the alcohol and its respective pH is the same with a minimal difference in bar heights.
#
#    The third graph is a bar graph plot of sulphates against alchohol. From the bar graph, it could be noticed that, there is a gradual increase in the height of the bars and when it got to the peak, there was a gradual fall. At the later part of the graph, there was an equilibrium. This shows how the content of the sulpates increases as the alcohol and at a point, the sulphate content decrease with an increase in the alcohol content. At a certain point, the content of the sulphate and the alcohol reaches equilibrium where both remains the same.
#
#    The fourth graph also represents a scatter graph that is used to determine the relationship between the two parameters which is the sulphate and the alcohol. From the scatter diagram, it could be deduced that there is a linear relationship between the two parameters indicating a strong relationship between them. This was clearly elaborated when the bargraph was plotted.
#
#    The next graph represents a bar graph which depicts the relationship between sulphates and pH with the difference in heights. From the bar graph, it can be deduced from the descending heights of the bars that, the two factors are inversely proportional. This means that, the high the sulphate content, the less the ph.
#
#    The last graph is a plot of sulphates against pH. From the graph, it could be noticed that, the highest sulphates had the least pH and then vice versa.This also gives a clear picture of the connectivity between the sulphates and the pH.
